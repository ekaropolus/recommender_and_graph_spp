# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaropolus/recommender_and_graph_spp/blob/main/Google%20Colab%20Notebooks/DS_Neo4j_ExpertIA_Sustainable_Public_Policies_MX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install neo4j
! pip install expertai-nlapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 173 kB 30.0 MB/s
# ...
#   Created wheel for neo4j: filename=neo4j-5.1.0-py3-none-any.whl size=248097 sha256=2c0bcc458a9c6fa3e03131a1a532d15b4e54b7fbeb6ddb6aacc09dc740b3fa64
#   Stored in directory: /root/.cache/pip/wheels/64/96/da/c30ec8577a970eadecc436103fbcbf7af1d6398d0ebe32cbab
# Successfully built neo4j
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 97 kB 6.7 MB/s
# ...

# %%
from neo4j import GraphDatabase
import logging
from neo4j.exceptions import ServiceUnavailable
import pandas as pd
import json
import os
from expertai.nlapi.cloud.client import ExpertAiClient

# %%
os.environ["EAI_USERNAME"] = 'hi@hadox.org'
os.environ["EAI_PASSWORD"] = 'RYD.Lq5Et4nT4T4'
client = ExpertAiClient()
language= 'es'

# %%
# %cd /content/drive/MyDrive/Proyectos 2022/01 Hackahton Expert.ia Neurolitks
# Out:
# /content/drive/MyDrive/Proyectos 2022/01 Hackahton Expert.ia Neurolitks

# %%
df_pp = pd.read_parquet('df_pp_2.parquet.gzip')

# %%
df_pp.head()
# Out:
#     id group                                        description  \
# 0  AG1     1  i. aguascalientes educado, integrado y equitativo
# 1  AG2     1         ii. aguascalientes derecho, seguro y libre
# 2  AG3     1  iii. aguascalientes con gobierno íntegro, aust...
# 3  AG4     1  iv. aguascalientes competitivo, diversificado ...
# 4  AG5     1  v. aguascalientes responsable, sostenible y li...
#
#                                               lemmas  \
# 0  [{'id': 'AG1', 'score': 44.09, 'value': 'educa...
# 1  [{'id': 'AG2', 'score': 99.0, 'value': 'ii. ag...
# 2  [{'id': 'AG3', 'score': 46.59, 'value': 'gobie...
# 3  [{'id': 'AG4', 'score': 43.79, 'value': 'diver...
# 4  [{'id': 'AG5', 'score': 90.19, 'value': 'v. ag...
#
#                                              syncons
# 0  [{'id': 'AG1', 'lemma': 'cortés', 'score': 43....
# 1  [{'id': 'AG2', 'lemma': 'derecho', 'score': 5....
# 2  [{'id': 'AG3', 'lemma': 'ministerio', 'score':...
# ...

# %%
from itertools import chain
df_lemmas = pd.DataFrame(list(chain.from_iterable(df_pp["lemmas"])))

# %%
df_lemmas.head()
# Out:
#     id  score               value
# 0  AG1  44.09             educado
# 1  AG1  38.59           integrado
# 2  AG1  15.10          equitativo
# 3  AG2  99.00  ii. aguascalientes
# 4  AG3  46.59            gobierno

# %%
df_syncons = pd.DataFrame(list(chain.from_iterable(df_pp["syncons"])))

# %%
df_syncons.head()
# Out:
#     id      lemma  score
# 0  AG1     cortés  43.09
# 1  AG1  integrado  38.40
# 2  AG1      justo  15.69
# 3  AG2    derecho   5.69
# 4  AG2     cierto   5.40

# %%
df_politic_lemmas = pd.merge(df_pp, df_lemmas, how='inner', on = 'id')

# %%
df_politic_lemmas.drop(['lemmas', 'syncons'], axis=1, inplace = True)

# %%
df_politic_lemmas.head()
# Out:
#     id group                                        description  score  \
# 0  AG1     1  i. aguascalientes educado, integrado y equitativo  44.09
# 1  AG1     1  i. aguascalientes educado, integrado y equitativo  38.59
# 2  AG1     1  i. aguascalientes educado, integrado y equitativo  15.10
# 3  AG2     1         ii. aguascalientes derecho, seguro y libre  99.00
# 4  AG3     1  iii. aguascalientes con gobierno íntegro, aust...  46.59
#
#                 value
# 0             educado
# 1           integrado
# 2          equitativo
# 3  ii. aguascalientes
# 4            gobierno

# %%
df_politic_lemmas.to_csv("politic_lemas.csv")

# %%
df_politic_syncons = pd.merge(df_pp, df_syncons, how='inner', on = 'id')

# %%
df_politic_syncons.drop(['lemmas', 'syncons'], axis=1, inplace = True)

# %%
df_politic_syncons.head()
# Out:
#     id group                                        description      lemma  \
# 0  AG1     1  i. aguascalientes educado, integrado y equitativo     cortés
# 1  AG1     1  i. aguascalientes educado, integrado y equitativo  integrado
# 2  AG1     1  i. aguascalientes educado, integrado y equitativo      justo
# 3  AG2     1         ii. aguascalientes derecho, seguro y libre    derecho
# 4  AG2     1         ii. aguascalientes derecho, seguro y libre     cierto
#
#    score
# 0  43.09
# 1  38.40
# 2  15.69
# 3   5.69
# 4   5.40

# %%
df_politic_syncons.to_csv("politic_syncons.csv")
